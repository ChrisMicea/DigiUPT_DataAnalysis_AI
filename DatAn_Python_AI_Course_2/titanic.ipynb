# %%
import pandas as pd

# %%
df = pd.read_excel('titanic.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_excel('titanic.xlsx')
#
# File /home/work/WORK/Coding Projects/Data Analysis/DatAn_Python_AI_Course/lib/python3.13/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
# ...

# %%
df = pd.read_excel('titanic.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_excel('titanic.xlsx')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df = pd.read_excel('titanic.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_excel('titanic.xlsx')
#
# File /home/work/WORK/Coding Projects/Data Analysis/DatAn_Python_AI_Course/lib/python3.13/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
# ...

# %%
df = pd.read_excel('data/titanic.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /home/work/WORK/Coding Projects/Data Analysis/DatAn_Python_AI_Course/lib/python3.13/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /usr/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]━━ 1/2 [openpyxl]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel('titanic.xlsx')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1 = pd.read_excel('titanic.xlsx', sheet_name='titanic class 1')

# %%
df1 = pd.read_excel('data/titanic.xlsx', sheet_name='titanic class 1')
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         1       1
# 1            2         1       1
# 2            3         0       1
# 3            4         1       1
# 4            5         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                            McCarthy, Mr. Timothy J    male  54.0      0
# 3                           Bonnell, Miss. Elizabeth  female  58.0      0
# 4                       Sloper, Mr. William Thompson    male  28.0      0
#
#    Parch    Ticket     Fare Cabin Embarked
# 0      0  PC 17599  71.2833   C85        C
# 1      0    113803  53.1000  C123        S
# 2      0     17463  51.8625   E46        S
# 3      0    113783  26.5500  C103        S
# 4      0    113788  35.5000    A6        S

# %%
df2 = pd.read_excel('titanic.xlsx', sheet_name='titanic class 2')

# %%
df2 = pd.read_excel('data/titanic.xlsx', sheet_name='titanic class 2')

# %%
df_fin
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         1       1
# 1              2         1       1
# 2              3         0       1
# 3              4         1       1
# 4              5         1       1
# ..           ...       ...     ...
# 179          180         1       2
# 180          181         1       2
# 181          182         1       2
# 182          183         0       2
# 183          184         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                              McCarthy, Mr. Timothy J    male  54.0      0
# 3                             Bonnell, Miss. Elizabeth  female  58.0      0
# 4                         Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1 = df1[['PassengerId', 'Survived', 'Pclass', 'Sex', 'Embarked']]
df2 = df2[['PassengerId', 'Survived', 'Pclass', 'Embarked']]
df_fin = pd.concat([df1, df2], axis=1)
df_fin
# Out:
#      PassengerId  Survived  Pclass     Sex Embarked  PassengerId  Survived  \
# 0              1         1       1  female        C          1.0       1.0
# 1              2         1       1  female        S          2.0       1.0
# 2              3         0       1    male        S          3.0       1.0
# 3              4         1       1  female        S          4.0       0.0
# 4              5         1       1    male        S          5.0       1.0
# ..           ...       ...     ...     ...      ...          ...       ...
# 211          212         1       1  female        S          NaN       NaN
# 212          213         0       1    male        S          NaN       NaN
# 213          214         1       1  female        C          NaN       NaN
# 214          215         1       1  female        S          NaN       NaN
# 215          216         1       1    male        C          NaN       NaN
#
#      Pclass Embarked
# 0       2.0        C
# 1       2.0        S
# ...

# %%
df_fin = pd.concat([df1, df2], axis=0, join='outer')
df_fin
# Out:
#      PassengerId  Survived  Pclass     Sex Embarked
# 0              1         1       1  female        C
# 1              2         1       1  female        S
# 2              3         0       1    male        S
# 3              4         1       1  female        S
# 4              5         1       1    male        S
# ..           ...       ...     ...     ...      ...
# 179          180         1       2     NaN        C
# 180          181         1       2     NaN        C
# 181          182         1       2     NaN        S
# 182          183         0       2     NaN        S
# 183          184         0       2     NaN        S
#
# [400 rows x 5 columns]

# %%
df_fin = pd.concat([df1, df2], axis=0, join='inner')
df_fin
# Out:
#      PassengerId  Survived  Pclass Embarked
# 0              1         1       1        C
# 1              2         1       1        S
# 2              3         0       1        S
# 3              4         1       1        S
# 4              5         1       1        S
# ..           ...       ...     ...      ...
# 179          180         1       2        C
# 180          181         1       2        C
# 181          182         1       2        S
# 182          183         0       2        S
# 183          184         0       2        S
#
# [400 rows x 4 columns]

# %%
df_fin = pd.merge(df1, df2, on='PassengerId')
df_fin
# Out:
#      PassengerId  Survived_x  Pclass_x     Sex Embarked_x  Survived_y  \
# 0              1           1         1  female          C           1
# 1              2           1         1  female          S           1
# 2              3           0         1    male          S           1
# 3              4           1         1  female          S           0
# 4              5           1         1    male          S           1
# ..           ...         ...       ...     ...        ...         ...
# 179          180           1         1    male          C           1
# 180          181           1         1    male          S           1
# 181          182           0         1    male          S           1
# 182          183           1         1  female          C           0
# 183          184           0         1    male          S           0
#
#      Pclass_y Embarked_y
# 0           2          C
# 1           2          S
# 2           2          S
# ...

# %%
df_fin = pd.merge(df1, df2, on='PassengerId', how='left')
df_fin
# Out:
#      PassengerId  Survived_x  Pclass_x     Sex Embarked_x  Survived_y  \
# 0              1           1         1  female          C         1.0
# 1              2           1         1  female          S         1.0
# 2              3           0         1    male          S         1.0
# 3              4           1         1  female          S         0.0
# 4              5           1         1    male          S         1.0
# ..           ...         ...       ...     ...        ...         ...
# 211          212           1         1  female          S         NaN
# 212          213           0         1    male          S         NaN
# 213          214           1         1  female          C         NaN
# 214          215           1         1  female          S         NaN
# 215          216           1         1    male          C         NaN
#
#      Pclass_y Embarked_y
# 0         2.0          C
# 1         2.0          S
# 2         2.0          S
# ...

# %%
df_fin = pd.merge(df1, df2, on='PassengerId', how='right')
df_fin
# Out:
#      PassengerId  Survived_x  Pclass_x     Sex Embarked_x  Survived_y  \
# 0              1           1         1  female          C           1
# 1              2           1         1  female          S           1
# 2              3           0         1    male          S           1
# 3              4           1         1  female          S           0
# 4              5           1         1    male          S           1
# ..           ...         ...       ...     ...        ...         ...
# 179          180           1         1    male          C           1
# 180          181           1         1    male          S           1
# 181          182           0         1    male          S           1
# 182          183           1         1  female          C           0
# 183          184           0         1    male          S           0
#
#      Pclass_y Embarked_y
# 0           2          C
# 1           2          S
# 2           2          S
# ...

# %%
df_fin = pd.merge(df1, df2, on='PassengerId', how='outer')
df_fin
# Out:
#      PassengerId  Survived_x  Pclass_x     Sex Embarked_x  Survived_y  \
# 0              1           1         1  female          C         1.0
# 1              2           1         1  female          S         1.0
# 2              3           0         1    male          S         1.0
# 3              4           1         1  female          S         0.0
# 4              5           1         1    male          S         1.0
# ..           ...         ...       ...     ...        ...         ...
# 211          212           1         1  female          S         NaN
# 212          213           0         1    male          S         NaN
# 213          214           1         1  female          C         NaN
# 214          215           1         1  female          S         NaN
# 215          216           1         1    male          C         NaN
#
#      Pclass_y Embarked_y
# 0         2.0          C
# 1         2.0          S
# 2         2.0          S
# ...

# %%
df_fin = pd.merge(df1, df2, left_on='PassengerId', right_on='PassengerId')
df_fin
# Out:
#      PassengerId  Survived_x  Pclass_x     Sex Embarked_x  Survived_y  \
# 0              1           1         1  female          C           1
# 1              2           1         1  female          S           1
# 2              3           0         1    male          S           1
# 3              4           1         1  female          S           0
# 4              5           1         1    male          S           1
# ..           ...         ...       ...     ...        ...         ...
# 179          180           1         1    male          C           1
# 180          181           1         1    male          S           1
# 181          182           0         1    male          S           1
# 182          183           1         1  female          C           0
# 183          184           0         1    male          S           0
#
#      Pclass_y Embarked_y
# 0           2          C
# 1           2          S
# 2           2          S
# ...

# %%
df_fin = pd.merge(df1, df2, left_on='PassengerId', right_on='PassengerId', suffixes=('_left', '_right'))
df_fin
# Out:
#      PassengerId  Survived_left  Pclass_left     Sex Embarked_left  \
# 0              1              1            1  female             C
# 1              2              1            1  female             S
# 2              3              0            1    male             S
# 3              4              1            1  female             S
# 4              5              1            1    male             S
# ..           ...            ...          ...     ...           ...
# 179          180              1            1    male             C
# 180          181              1            1    male             S
# 181          182              0            1    male             S
# 182          183              1            1  female             C
# 183          184              0            1    male             S
#
#      Survived_right  Pclass_right Embarked_right
# 0                 1             2              C
# 1                 1             2              S
# ...
